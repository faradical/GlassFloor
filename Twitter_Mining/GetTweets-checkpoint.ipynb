# %%
import requests
import bs4
import pandas as pd
import sys
from splinter import Browser
import time

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

keyword = str(sys.argv[1])
url = f'https://twitter.com/search?q=%23{keyword}'

browser.visit(url)
def wait_for_element(tag, browser):
    if browser.is_element_present_by_tag(tag, wait_time=1) != True:
        return wait_for_element(tag, browser)
    else:
        print(tag + " found")
        
wait_for_element("article", browser)
articles = []

for i in range(0, 10):
    browser.execute_script("window.scrollTo(2000, document.body.scrollHeight);")
    time.sleep(1)
    soup = bs4.BeautifulSoup(browser.html)
    for a in soup.find_all("article"):
        if a not in articles:
            articles.append(a)

len(articles)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-105-d808344fa85e> in <module>
#      12         print(tag + " found")
#      13
# ---> 14 wait_for_element("article", browser)
#      15 articles = []
#      16
#
# <ipython-input-105-d808344fa85e> in wait_for_element(tag, browser)
#       8 def wait_for_element(tag, browser):
#       9     if browser.is_element_present_by_tag(tag, wait_time=1) != True:
# ---> 10         return wait_for_element(tag, browser)
#      11     else:
#      12         print(tag + " found")
#
# <ipython-input-105-d808344fa85e> in wait_for_element(tag, browser)
#       8 def wait_for_element(tag, browser):
#       9     if browser.is_element_present_by_tag(tag, wait_time=1) != True:
# ---> 10         return wait_for_element(tag, browser)
#      11     else:
#      12         print(tag + " found")
#
# <ipython-input-105-d808344fa85e> in wait_for_element(tag, browser)
#       8 def wait_for_element(tag, browser):
#       9     if browser.is_element_present_by_tag(tag, wait_time=1) != True:
# ---> 10         return wait_for_element(tag, browser)
#      11     else:
#      12         print(tag + " found")
#
# <ipython-input-105-d808344fa85e> in wait_for_element(tag, browser)
#       8 def wait_for_element(tag, browser):
#       9     if browser.is_element_present_by_tag(tag, wait_time=1) != True:
# ---> 10         return wait_for_element(tag, browser)
#      11     else:
#      12         print(tag + " found")
#
# <ipython-input-105-d808344fa85e> in wait_for_element(tag, browser)
#       8 def wait_for_element(tag, browser):
#       9     if browser.is_element_present_by_tag(tag, wait_time=1) != True:
# ---> 10         return wait_for_element(tag, browser)
#      11     else:
#      12         print(tag + " found")
#
# <ipython-input-105-d808344fa85e> in wait_for_element(tag, browser)
#       8 def wait_for_element(tag, browser):
#       9     if browser.is_element_present_by_tag(tag, wait_time=1) != True:
# ---> 10         return wait_for_element(tag, browser)
#      11     else:
#      12         print(tag + " found")
#
# <ipython-input-105-d808344fa85e> in wait_for_element(tag, browser)
#       7 browser.visit(url)
#       8 def wait_for_element(tag, browser):
# ----> 9     if browser.is_element_present_by_tag(tag, wait_time=1) != True:
#      10         return wait_for_element(tag, browser)
#      11     else:
#
# ~\Anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in is_element_present_by_tag(self, tag, wait_time)
#     399
#     400     def is_element_present_by_tag(self, tag, wait_time=None):
# --> 401         return self.is_element_present(self.find_by_tag, tag, wait_time)
#     402
#     403     def is_element_not_present_by_tag(self, tag, wait_time=None):
#
# ~\Anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in is_element_present(self, finder, selector, wait_time)
#     373
#     374         while time.time() < end_time:
# --> 375             if finder(selector, wait_time=wait_time):
#     376                 return True
#     377         return False
#
# ~\Anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in find_by_tag(self, tag, wait_time)
#     569             self.driver.find_elements_by_tag_name,
#     570             tag,
# --> 571             wait_time=wait_time,
#     572     )
#     573
#
# ~\Anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in find_by(self, finder, selector, original_find, original_query, wait_time)
#     279
#     280         while time.time() < end_time:
# --> 281             elem_list = _find(self, finder, selector)
#     282
#     283             if elem_list:
#
# ~\Anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in _find(self, finder, selector)
#     239
#     240     try:
# --> 241         elements = finder(selector)
#     242         if not isinstance(elements, list):
#     243             elements = [elements]
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_tag_name(self, name)
#     544             elements = driver.find_elements_by_tag_name('h1')
#     545         """
# --> 546         return self.find_elements(by=By.TAG_NAME, value=name)
#     547
#     548     def find_element_by_class_name(self, name):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#    1005         return self.execute(Command.FIND_ELEMENTS, {
#    1006             'using': by,
# -> 1007             'value': value})['value'] or []
#    1008
#    1009     @property
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=79.0.3945.130)

# %%
tweets = []
for a in articles:
    try:
        username = a.find('div', class_="css-1dbjc4n r-1awozwy r-18u37iz r-dnmrzs").find("span").find("span").contents[0]
        handle = a.find('div', class_="css-1dbjc4n r-18u37iz r-1wbh5a2 r-1f6r7vd").find("span").contents[0]
        tweet_contents = a.find('div', class_="css-901oao r-hkyrab r-1qd0xha r-a023e6 r-16dba41 r-ad9z0x r-bcqeeo r-bnwqim r-qvutc0")
        time = a.find('time')['datetime']
        tweet_contents_list = [c.get_text() for c in tweet_contents.children if c.get_text() != '']
        tweet_text = ''.join(tweet_contents_list).replace("\n","")
    except:
        tweet_text = ''

    tweets.append({'username':username, 'handle':handle, 'tweet_text':tweet_text, 'time':time})

tweets
# Out:
# [{'username': 'Suzanne Cutway',
#   'handle': '@scutway',
#   'tweet_text': 'So grateful to work with such an amazing group of people! Go Team Services!!! #SPM2020 #homedepot #homeservices #planningcommittee #90s',
#   'time': '2020-02-12T13:36:03.000Z'},
#  {'username': 'Michael Tullier, APR',
#   'handle': '@michaeltullier',
#   'tweet_text': "Retweet this tweet to help #TuskegeeUniversity win $50,000 in this year's #HomeDepot #RetoolYourSchool competition -- or add #tuskegee_rys20 to your own tweets! @TuskegeeUniv",
#   'time': '2020-02-14T21:24:09.000Z'},
#  {'username': 'Johnny Atoe',
#   'handle': '@JohnnyAtoe',
#   'tweet_text': 'Happy HD Anniversary to these guys! Jeff/COS, Steve/Garden, Jake/Lot, Gunner/Tool Rental! Thank you for all you do! 50 combined years between these 4 gentlemen right here!! #allin #homedepot #bleedorange @PayetteBilly @steve_zeiss @asm_1018FQ @LaneyAgliam @NotoKara @JabarrBean',
#   'time': '2020-02-14T21:33:28.000Z'},
#  {'username': 'Rachel Avalos-Kiblinger',
#   'handle': '@rachelavalos510',
#   'tweet_text': 'Perfect day to team build with my Mighty LB crew.  #SF #alcatraz #teambuild #HomeDepot',
#   'time': '2020-02-12T05:50:22.000Z'},
#  {'username': 'Meg G.',
#   'handle': '@Megsytopolis1',
#   'tweet_text': "So I got 5 candy grams at work for Valentine's Day. #HomeDepot #2575 showing that we all care for each other! Love my store!",
#   'time': '2020-02-15T04:54:05.000Z'},
#  {'username': 'Brandi Garin',
#   'handle': '@BrandiGarin',
#   'tweet_text': '#D154 Awesome day at Garlic Fest!!! Great job Team 205 for hosting the event  #HomeDepot #KidsWorkshop #GivingBack #1RegionSFL',
#   'time': '2020-02-09T03:45:12.000Z'},
#  {'username': 'Sunamita Morales',
#   'handle': '@SunamitaMorales',
#   'tweet_text': 'Happy Valentine’s Day Y’all!!  #MDO5837 #HomeDepot @THD_MDO5837 @DashMaw @MauriceRoberso3 @denisrey322 @travissbarton @sharondperkins',
#   'time': '2020-02-14T15:12:31.000Z'},
#  {'username': 'Theresa',
#   'handle': '@Theresa_PBF',
#   'tweet_text': 'Good Morning All #Doers at #HomeDepot Garden Centers. We stocked your Tables with Package Roses Cyclamen Spring,Potted Bulbs Pansies,Violas, lots of Late Winter Color & Succulents so you can Do More for your Garden Shoppers #SaturdayShopping',
#   'time': '2020-02-15T15:47:52.000Z'},
#  {'username': 'Theresa',
#   'handle': '@Theresa_PBF',
#   'tweet_text': '',
#   'time': '2020-02-15T15:47:52.000Z'},
#  {'username': 'danny anthony',
#   'handle': '@auydaplease',
#   'tweet_text': 'This morning, I looked at my paycheck and I cried. How can I work for a company who in 2019 3rd quarter made 27.2 billion an increase of 3.5% from 3rd quarter 2019. The Ceo made over 11million and the stock is at $243 & i can’t pay my bills. @AMCTHD #homedepot #قاطعوا_محمد_رمضان',
#   'time': '2020-02-14T15:17:48.000Z'},
#  {'username': 'Humberto Romero',
#   'handle': '@humberto1romero',
#   'tweet_text': 'Our DM @Chris_Fraga_HD with SM @VictorAEsposit1 recognizing our very own Rich for his 30yrs of Service with this wonderful company. By the way Rich runs a lean mean Receiving Machine at 222. @JoeRSantelia #30yrsOfService #HomeDepot',
#   'time': '2020-02-12T01:33:55.000Z'},
#  {'username': 'Colleen Bethel',
#   'handle': '@Cleenbeth1',
#   'tweet_text': 'This is why I love #HomeDepot. RAFAEL IS IN THE POLAR ZONE...LOL',
#   'time': '2020-02-11T14:27:14.000Z'},
#  {'username': 'Suzanne Cutway',
#   'handle': '@scutway',
#   'tweet_text': 'Doors opening soon for general session! #SPM2020 #homedepot #homeservices #partnershipmeeting',
#   'time': '2020-02-11T13:20:11.000Z'},
#  {'username': 'Ghostbusters News',
#   'handle': '@GBNewsdotcom',
#   'tweet_text': 'COMING SOON: Inflatable Ghostbusters Ecto-1 with Slimer! MORE INFO: https://ghostbustersnews.com/2020/02/13/coming-soon-new-inflatable-ecto-1-with-slimer/…#ghostbusters #slimer #ecto1 #inflatable #halloween #comingsoon #homedepot #whoyougonnacall #afterlife #sony #ghostcorps',
#   'time': '2020-02-13T15:34:37.000Z'},
#  {'username': 'Lenny Getz',
#   'handle': '@GetzLenny',
#   'tweet_text': "#HomeDepotUpdate on friend's bad tile installation from Home Depot Hollywood Florida. Store manager Omar is supposed to call by 3 for when the are going to come see it. They have always cancelled in the past. Maybe this time they will actually show up.",
#   'time': '2020-02-12T18:41:33.000Z'},
#  {'username': 'Rios4598',
#   'handle': '@rios4598',
#   'tweet_text': 'Teaching, training and developing his associates while executing DOTD!! Great job Hugo (D21/22 DS)!! D22 ready for its pros! #santaana #HomeDepot #606 @ANewmanhd @homedepot606 @Yesenia_ASM0606 @Elliottwakeman3 @Michael82376917 @Jaime_HD_D25 @Steven_Mousseau',
#   'time': '2020-02-12T19:35:47.000Z'},
#  {'username': 'Florsabel De La Rosa',
#   'handle': '@Florsabel_HD',
#   'tweet_text': 'This bunch was just awesome today!thank you team morrow for participating today & learning about HDIS.the more you know the better equipped you are to help our customers #Homedepot #homeservices #windowknowledge @Carell_R @Frankparas @RichTempelman now go set those appointments',
#   'time': '2020-02-11T15:54:13.000Z'},
#  {'username': 'Wendy Contreras',
#   'handle': '@wendyCcontreras',
#   'tweet_text': 'VOA 2020What a great 2019, so many accomplishments to be proud of! Let’s continue a new year of success! Thank you 2304 for all you do! #voiceoftheassociate #homedepot',
#   'time': '2020-02-12T18:09:03.000Z'}]

# %%
tweetsDF = pd.DataFrame(tweets)
tweetsDF.to_csv("tweets_test.csv", index=False)

# %%
tweetsDF
# Out:
#                    username            handle  \
# 0            Suzanne Cutway          @scutway
# 1      Michael Tullier, APR   @michaeltullier
# 2               Johnny Atoe       @JohnnyAtoe
# 3   Rachel Avalos-Kiblinger  @rachelavalos510
# 4                    Meg G.    @Megsytopolis1
# 5              Brandi Garin      @BrandiGarin
# 6          Sunamita Morales  @SunamitaMorales
# 7                   Theresa      @Theresa_PBF
# 8                   Theresa      @Theresa_PBF
# 9             danny anthony      @auydaplease
# 10          Humberto Romero  @humberto1romero
# 11           Colleen Bethel       @Cleenbeth1
# 12           Suzanne Cutway          @scutway
# 13        Ghostbusters News     @GBNewsdotcom
# 14               Lenny Getz        @GetzLenny
# 15                 Rios4598         @rios4598
# 16     Florsabel De La Rosa     @Florsabel_HD
# 17          Wendy Contreras  @wendyCcontreras
#
#                                            tweet_text  \
# 0   So grateful to work with such an amazing group...
# 1   Retweet this tweet to help #TuskegeeUniversity...
# 2   Happy HD Anniversary to these guys! Jeff/COS, ...
# 3   Perfect day to team build with my Mighty LB cr...
# 4   So I got 5 candy grams at work for Valentine's...
# 5   #D154 Awesome day at Garlic Fest!!! Great job ...
# 6   Happy Valentine’s Day Y’all!!  #MDO5837 #HomeD...
# 7   Good Morning All #Doers at #HomeDepot Garden C...
# 8
# 9   This morning, I looked at my paycheck and I cr...
# 10  Our DM @Chris_Fraga_HD with SM @VictorAEsposit...
# 11  This is why I love #HomeDepot. RAFAEL IS IN TH...
# 12  Doors opening soon for general session! #SPM20...
# 13  COMING SOON: Inflatable Ghostbusters Ecto-1 wi...
# 14  #HomeDepotUpdate on friend's bad tile installa...
# 15  Teaching, training and developing his associat...
# 16  This bunch was just awesome today!thank you te...
# 17  VOA 2020What a great 2019, so many accomplishm...
#
#                         time
# 0   2020-02-12T13:36:03.000Z
# 1   2020-02-14T21:24:09.000Z
# 2   2020-02-14T21:33:28.000Z
# 3   2020-02-12T05:50:22.000Z
# 4   2020-02-15T04:54:05.000Z
# 5   2020-02-09T03:45:12.000Z
# 6   2020-02-14T15:12:31.000Z
# 7   2020-02-15T15:47:52.000Z
# 8   2020-02-15T15:47:52.000Z
# 9   2020-02-14T15:17:48.000Z
# 10  2020-02-12T01:33:55.000Z
# 11  2020-02-11T14:27:14.000Z
# 12  2020-02-11T13:20:11.000Z
# 13  2020-02-13T15:34:37.000Z
# 14  2020-02-12T18:41:33.000Z
# 15  2020-02-12T19:35:47.000Z
# 16  2020-02-11T15:54:13.000Z
# 17  2020-02-12T18:09:03.000Z
